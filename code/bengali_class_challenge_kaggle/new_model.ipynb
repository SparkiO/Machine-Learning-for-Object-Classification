# %% [markdown]
# ### Loading Files

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet

# %%
def change_size(df):
    preprocessed = {}
    for i in range(df.shape[0]):
        image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(64,64))
        image = image.reshape(-1)
        preprocessed[df.index[i]] = image
        
    preprocessed = pd.DataFrame(preprocessed).T
    return preprocessed

# %% [markdown]
# ### Model:

# %%
import tensorflow
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Activation, Conv2D, Flatten, Concatenate, GlobalAveragePooling2D, MaxPooling2D, AveragePooling2D, MaxPool2D, Dropout, BatchNormalization, Input, LeakyReLU
from tensorflow.keras import regularizers

inputs = Input(shape = (64, 64, 1))

VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(inputs)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(5, 5), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=512, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

#Classification Part
VGG_adjusted = Flatten()(VGG_adjusted)
VGG_adjusted = Dense(1024, activation = "relu")(VGG_adjusted)
VGG_adjusted = Dropout(0.30)(VGG_adjusted)
VGG_adjusted = Dense(512, activation = "relu")(VGG_adjusted)
VGG_adjusted = Dropout(0.10)(VGG_adjusted)

root = Dense(168, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='activation_1_root')(VGG_adjusted) 
vowel = Dense(11, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='activation_2_vowel')(VGG_adjusted) 
consonant = Dense(7, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='final_activation_consonant')(VGG_adjusted)

VGG_adjusted = Model(inputs=inputs, outputs=[root, vowel, consonant])

# %%
VGG_adjusted.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   102464      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    2359808     conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 512)    6554112     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 2, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2, 2, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1_root (Dense)       (None, 168)          86184       dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_2_vowel (Dense)      (None, 11)           5643        dropout_6[0][0]
# __________________________________________________________________________________________________
# final_activation_consonant (Den (None, 7)            3591        dropout_6[0][0]
# ==================================================================================================
# Total params: 16,952,410
# Trainable params: 16,948,442
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(VGG_adjusted)

# %%
from tensorflow.keras.optimizers import Adam

VGG_adjusted.compile(
        optimizer = Adam(lr= 1E-3, epsilon = 1e-8), 
        loss = "categorical_crossentropy", 
        metrics = ['accuracy']
        )

# %%
class DataGenerator(tensorflow.keras.preprocessing.image.ImageDataGenerator):
    
    def flow(self,x, y=None, batch_size=64, shuffle=True): 
        labels = None 
        keys = {} 
        ordered = []
        
        for key, value in y.items():
            labels = value if (labels is None) else (np.concatenate((labels, value), axis=1))
            keys[key] = value.shape[1] 
            ordered.append(key)

        for output_x, output_y in super().flow(x, labels, batch_size=64):
            label_dict = {}
            pos = 0
            
            for label in ordered:
                target_length = keys[label]
                label_dict[label] = output_y[:, pos: pos + target_length] 
                pos += target_length

            yield output_x, label_dict

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping 

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.1, mode="min", min_lr = 0.00001)
checkpoint = ModelCheckpoint('best_model_vgg_try.h5', monitor ='val_loss', save_best_only = True, save_weights_only=True)

callbacks = [reduce_learning_rate, checkpoint]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Training:

# %%
import gc
import tqdm
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv('../input/bengaliai-cv19/train.csv')

# %%
import cv2

# %%
histories = []
for i in range(4):
    print('Loading file:', i)
    df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df, on='image_id')

    grapheme = pd.get_dummies(df['grapheme_root']).values
    vowel = pd.get_dummies(df['vowel_diacritic']).values  
    consonant = pd.get_dummies(df['consonant_diacritic']).values

    df.drop(['image_id','grapheme_root','vowel_diacritic','consonant_diacritic','grapheme'], axis=1,inplace=True)
    df = change_size(df).astype('float32')

    df = df.values.reshape(-1, 64, 64, 1)
    df, test_x, train_graph_y, test_graph_y, train_vowel_y, test_vowel_y, train_cons_y, test_cons_y = train_test_split(df, grapheme,vowel,consonant, test_size=0.20)

    del grapheme
    del vowel
    del consonant
    gc.collect()

    gen = DataGenerator(rotation_range= 15, 
                        zoom_range = 0.10,
                        width_shift_range=0.10,
                        height_shift_range=0.10
                       )


    gen.fit(df)
    print('Training:')
    history = VGG_adjusted.fit_generator(gen.flow(df, {'activation_1_root': train_graph_y, 'activation_2_vowel': train_vowel_y, 'final_activation_consonant': train_cons_y}, batch_size= 64),
                                      epochs = 25,
                                      validation_data = (test_x, [test_graph_y, test_vowel_y, test_cons_y]),
                                      steps_per_epoch= df.shape[0] // 64,
                                      callbacks= callbacks,
                                      shuffle=True)
    histories.append(history)
    del history
    del df
    del test_vowel_y
    del train_cons_y
    del test_cons_y
    del gen
    del test_x
    del train_graph_y
    del test_graph_y
    del train_vowel_y
    gc.collect()
# Out:
# Loading file: 0
# Training:
# Train for 627 steps, validate on 10042 samples
# Epoch 1/25
# 627/627 [==============================] - 46s 73ms/step - loss: 7.8416 - activation_1_root_loss: 4.6859 - activation_2_vowel_loss: 1.3902 - final_activation_consonant_loss: 1.2072 - activation_1_root_accuracy: 0.0318 - activation_2_vowel_accuracy: 0.5085 - final_activation_consonant_accuracy: 0.6237 - val_loss: 9.3042 - val_activation_1_root_loss: 5.0071 - val_activation_2_vowel_loss: 2.7877 - val_final_activation_consonant_loss: 1.3420 - val_activation_1_root_accuracy: 0.0096 - val_activation_2_vowel_accuracy: 0.2622 - val_final_activation_consonant_accuracy: 0.6191
# Epoch 2/25
# 627/627 [==============================] - 38s 61ms/step - loss: 6.2277 - activation_1_root_loss: 4.2897 - activation_2_vowel_loss: 0.7797 - final_activation_consonant_loss: 1.0009 - activation_1_root_accuracy: 0.0481 - activation_2_vowel_accuracy: 0.7362 - final_activation_consonant_accuracy: 0.6429 - val_loss: 7.4854 - val_activation_1_root_loss: 4.4493 - val_activation_2_vowel_loss: 1.6319 - val_final_activation_consonant_loss: 1.2485 - val_activation_1_root_accuracy: 0.0375 - val_activation_2_vowel_accuracy: 0.4523 - val_final_activation_consonant_accuracy: 0.5940
# Epoch 3/25
# 627/627 [==============================] - 37s 59ms/step - loss: 5.5432 - activation_1_root_loss: 3.9852 - activation_2_vowel_loss: 0.6285 - final_activation_consonant_loss: 0.7748 - activation_1_root_accuracy: 0.0661 - activation_2_vowel_accuracy: 0.7934 - final_activation_consonant_accuracy: 0.7159 - val_loss: 5.9144 - val_activation_1_root_loss: 4.1584 - val_activation_2_vowel_loss: 0.7894 - val_final_activation_consonant_loss: 0.8135 - val_activation_1_root_accuracy: 0.0584 - val_activation_2_vowel_accuracy: 0.7526 - val_final_activation_consonant_accuracy: 0.7135
# Epoch 4/25
# 627/627 [==============================] - 39s 62ms/step - loss: 4.9394 - activation_1_root_loss: 3.6843 - activation_2_vowel_loss: 0.5349 - final_activation_consonant_loss: 0.5624 - activation_1_root_accuracy: 0.0900 - activation_2_vowel_accuracy: 0.8327 - final_activation_consonant_accuracy: 0.7993 - val_loss: 4.6917 - val_activation_1_root_loss: 3.5815 - val_activation_2_vowel_loss: 0.5268 - val_final_activation_consonant_loss: 0.4260 - val_activation_1_root_accuracy: 0.1056 - val_activation_2_vowel_accuracy: 0.8374 - val_final_activation_consonant_accuracy: 0.8591
# Epoch 5/25
# 627/627 [==============================] - 37s 59ms/step - loss: 4.4203 - activation_1_root_loss: 3.3407 - activation_2_vowel_loss: 0.4698 - final_activation_consonant_loss: 0.4481 - activation_1_root_accuracy: 0.1294 - activation_2_vowel_accuracy: 0.8520 - final_activation_consonant_accuracy: 0.8500 - val_loss: 4.1720 - val_activation_1_root_loss: 3.2311 - val_activation_2_vowel_loss: 0.4006 - val_final_activation_consonant_loss: 0.3765 - val_activation_1_root_accuracy: 0.1435 - val_activation_2_vowel_accuracy: 0.8724 - val_final_activation_consonant_accuracy: 0.8759
# Epoch 6/25
# 627/627 [==============================] - 37s 59ms/step - loss: 3.9887 - activation_1_root_loss: 3.0129 - activation_2_vowel_loss: 0.4230 - final_activation_consonant_loss: 0.3850 - activation_1_root_accuracy: 0.1781 - activation_2_vowel_accuracy: 0.8681 - final_activation_consonant_accuracy: 0.8763 - val_loss: 4.2001 - val_activation_1_root_loss: 2.9765 - val_activation_2_vowel_loss: 0.5710 - val_final_activation_consonant_loss: 0.4853 - val_activation_1_root_accuracy: 0.1954 - val_activation_2_vowel_accuracy: 0.8211 - val_final_activation_consonant_accuracy: 0.8384
# Epoch 7/25
# 627/627 [==============================] - 38s 60ms/step - loss: 3.6278 - activation_1_root_loss: 2.7135 - activation_2_vowel_loss: 0.4003 - final_activation_consonant_loss: 0.3406 - activation_1_root_accuracy: 0.2288 - activation_2_vowel_accuracy: 0.8763 - final_activation_consonant_accuracy: 0.8933 - val_loss: 3.7225 - val_activation_1_root_loss: 2.6451 - val_activation_2_vowel_loss: 0.5184 - val_final_activation_consonant_loss: 0.3831 - val_activation_1_root_accuracy: 0.2528 - val_activation_2_vowel_accuracy: 0.8243 - val_final_activation_consonant_accuracy: 0.8787
# Epoch 8/25
# 627/627 [==============================] - 37s 59ms/step - loss: 3.2677 - activation_1_root_loss: 2.4065 - activation_2_vowel_loss: 0.3617 - final_activation_consonant_loss: 0.3231 - activation_1_root_accuracy: 0.2969 - activation_2_vowel_accuracy: 0.8909 - final_activation_consonant_accuracy: 0.9016 - val_loss: 2.7474 - val_activation_1_root_loss: 2.0671 - val_activation_2_vowel_loss: 0.2612 - val_final_activation_consonant_loss: 0.2422 - val_activation_1_root_accuracy: 0.3815 - val_activation_2_vowel_accuracy: 0.9200 - val_final_activation_consonant_accuracy: 0.9207
# Epoch 9/25
# 627/627 [==============================] - 38s 60ms/step - loss: 2.9481 - activation_1_root_loss: 2.1398 - activation_2_vowel_loss: 0.3382 - final_activation_consonant_loss: 0.2913 - activation_1_root_accuracy: 0.3605 - activation_2_vowel_accuracy: 0.8983 - final_activation_consonant_accuracy: 0.9101 - val_loss: 2.3801 - val_activation_1_root_loss: 1.7095 - val_activation_2_vowel_loss: 0.2473 - val_final_activation_consonant_loss: 0.2413 - val_activation_1_root_accuracy: 0.4713 - val_activation_2_vowel_accuracy: 0.9229 - val_final_activation_consonant_accuracy: 0.9267
# Epoch 10/25
# 627/627 [==============================] - 38s 60ms/step - loss: 2.6962 - activation_1_root_loss: 1.9216 - activation_2_vowel_loss: 0.3201 - final_activation_consonant_loss: 0.2738 - activation_1_root_accuracy: 0.4227 - activation_2_vowel_accuracy: 0.9049 - final_activation_consonant_accuracy: 0.9176 - val_loss: 2.2843 - val_activation_1_root_loss: 1.5747 - val_activation_2_vowel_loss: 0.2984 - val_final_activation_consonant_loss: 0.2332 - val_activation_1_root_accuracy: 0.5161 - val_activation_2_vowel_accuracy: 0.9145 - val_final_activation_consonant_accuracy: 0.9295
# Epoch 11/25
# 198/627 [========>.....................] - ETA: 23s - loss: 2.5504 - activation_1_root_loss: 1.7931 - activation_2_vowel_loss: 0.3055 - final_activation_consonant_loss: 0.2728 - activation_1_root_accuracy: 0.4570 - activation_2_vowel_accuracy: 0.9121 - final_activation_consonant_accuracy: 0.9182Training:
# Train for 627 steps, validate on 10042 samples
# Epoch 1/25
# 627/627 [==============================] - 38s 61ms/step - loss: 0.6930 - activation_1_root_loss: 0.3976 - activation_2_vowel_loss: 0.0981 - final_activation_consonant_loss: 0.0945 - activation_1_root_accuracy: 0.8904 - activation_2_vowel_accuracy: 0.9753 - final_activation_consonant_accuracy: 0.9734 - val_loss: 0.5842 - val_activation_1_root_loss: 0.3301 - val_activation_2_vowel_loss: 0.0830 - val_final_activation_consonant_loss: 0.0707 - val_activation_1_root_accuracy: 0.9167 - val_activation_2_vowel_accuracy: 0.9797 - val_final_activation_consonant_accuracy: 0.9815
# Epoch 11/25
# 627/627 [==============================] - 38s 61ms/step - loss: 0.6616 - activation_1_root_loss: 0.3789 - activation_2_vowel_loss: 0.0910 - final_activation_consonant_loss: 0.0928 - activation_1_root_accuracy: 0.8940 - activation_2_vowel_accuracy: 0.9767 - final_activation_consonant_accuracy: 0.9737 - val_loss: 0.5693 - val_activation_1_root_loss: 0.3204 - val_activation_2_vowel_loss: 0.0836 - val_final_activation_consonant_loss: 0.0684 - val_activation_1_root_accuracy: 0.9175 - val_activation_2_vowel_accuracy: 0.9803 - val_final_activation_consonant_accuracy: 0.9816
# Epoch 12/25
# 627/627 [==============================] - 38s 61ms/step - loss: 0.6536 - activation_1_root_loss: 0.3764 - activation_2_vowel_loss: 0.0872 - final_activation_consonant_loss: 0.0947 - activation_1_root_accuracy: 0.8937 - activation_2_vowel_accuracy: 0.9768 - final_activation_consonant_accuracy: 0.9734 - val_loss: 0.5683 - val_activation_1_root_loss: 0.3211 - val_activation_2_vowel_loss: 0.0831 - val_final_activation_consonant_loss: 0.0705 - val_activation_1_root_accuracy: 0.9171 - val_activation_2_vowel_accuracy: 0.9795 - val_final_activation_consonant_accuracy: 0.9816
# Epoch 13/25
# 627/627 [==============================] - 38s 61ms/step - loss: 0.5217 - activation_1_root_loss: 0.3013 - activation_2_vowel_loss: 0.0715 - final_activation_consonant_loss: 0.0749 - activation_1_root_accuracy: 0.9139 - activation_2_vowel_accuracy: 0.9810 - final_activation_consonant_accuracy: 0.9790 - val_loss: 0.5185 - val_activation_1_root_loss: 0.3026 - val_activation_2_vowel_loss: 0.0785 - val_final_activation_consonant_loss: 0.0638 - val_activation_1_root_accuracy: 0.9233 - val_activation_2_vowel_accuracy: 0.9818 - val_final_activation_consonant_accuracy: 0.9837
# Epoch 24/25
# 627/627 [==============================] - 39s 62ms/step - loss: 0.7266 - activation_1_root_loss: 0.4402 - activation_2_vowel_loss: 0.1087 - final_activation_consonant_loss: 0.1065 - activation_1_root_accuracy: 0.8844 - activation_2_vowel_accuracy: 0.9737 - final_activation_consonant_accuracy: 0.9712 - val_loss: 0.5038 - val_activation_1_root_loss: 0.2884 - val_activation_2_vowel_loss: 0.0655 - val_final_activation_consonant_loss: 0.0788 - val_activation_1_root_accuracy: 0.9214 - val_activation_2_vowel_accuracy: 0.9851 - val_final_activation_consonant_accuracy: 0.9784
# Epoch 8/25
# 627/627 [==============================] - 38s 61ms/step - loss: 0.6755 - activation_1_root_loss: 0.4089 - activation_2_vowel_loss: 0.0984 - final_activation_consonant_loss: 0.0997 - activation_1_root_accuracy: 0.8905 - activation_2_vowel_accuracy: 0.9753 - final_activation_consonant_accuracy: 0.9723 - val_loss: 0.4961 - val_activation_1_root_loss: 0.2840 - val_activation_2_vowel_loss: 0.0653 - val_final_activation_consonant_loss: 0.0784 - val_activation_1_root_accuracy: 0.9216 - val_activation_2_vowel_accuracy: 0.9852 - val_final_activation_consonant_accuracy: 0.9788
# Epoch 21/25
# 627/627 [==============================] - 40s 64ms/step - loss: 0.7132 - activation_1_root_loss: 0.4369 - activation_2_vowel_loss: 0.1094 - final_activation_consonant_loss: 0.1000 - activation_1_root_accuracy: 0.8862 - activation_2_vowel_accuracy: 0.9727 - final_activation_consonant_accuracy: 0.9726 - val_loss: 0.4707 - val_activation_1_root_loss: 0.2810 - val_activation_2_vowel_loss: 0.0629 - val_final_activation_consonant_loss: 0.0601 - val_activation_1_root_accuracy: 0.9253 - val_activation_2_vowel_accuracy: 0.9853 - val_final_activation_consonant_accuracy: 0.9830
# Epoch 4/25
# 500/627 [======================>.......] - ETA: 7s - loss: 0.6667 - activation_1_root_loss: 0.4051 - activation_2_vowel_loss: 0.0999 - final_activation_consonant_loss: 0.0972 - activation_1_root_accuracy: 0.8914 - activation_2_vowel_accuracy: 0.9755 - final_activation_consonant_accuracy: 0.9720

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
for history in histories:
    plt.figure(figsize=(25, 10), dpi=100)

    plt.title('Training Loss Graph', fontsize=25)
    plt.xlabel('Epoch', fontsize=20)
    plt.ylabel('Loss', fontsize=20)
    plt.ylim(0, 8)
    
    plt.plot(np.arange(0.0, 25), history.history['activation_1_root_loss'], label='train_root')
    plt.plot(np.arange(0.0, 25), history.history['activation_2_vowel_loss'], label='train_vowel')
    plt.plot(np.arange(0.0, 25), history.history['final_activation_consonant_loss'], label='train_consonant')

    plt.plot(np.arange(0.0, 25), history.history['val_activation_1_root_loss'], label='val_root')
    plt.plot(np.arange(0.0, 25), history.history['val_activation_2_vowel_loss'], label='val_vowel')
    plt.plot(np.arange(0.0, 25), history.history['val_final_activation_consonant_loss'], label='val_consonant')

    plt.legend(loc='upper right', fontsize=15)
    plt.show()

# %%
for history in histories:
    plt.figure(figsize=(25, 10), dpi=100)

    plt.title('Training Accuracy Graph', fontsize=25)
    plt.xlabel('Epoch', fontsize=20)
    plt.ylabel('Accuracy', fontsize=20)
    plt.ylim(0, 1)

    plt.plot(np.arange(0.0, 25), history.history['activation_1_root_accuracy'], label='train_root')
    plt.plot(np.arange(0.0, 25), history.history['activation_2_vowel_accuracy'], label='train_vowel')
    plt.plot(np.arange(0.0, 25), history.history['final_activation_consonant_accuracy'], label='train_consonant')

    plt.plot(np.arange(0.0, 25), history.history['val_activation_1_root_accuracy'], label='val_root')
    plt.plot(np.arange(0.0, 25), history.history['val_activation_2_vowel_accuracy'], label='val_vowel')
    plt.plot(np.arange(0.0, 25), history.history['val_final_activation_consonant_accuracy'], label='val_consonant')

    plt.legend(loc='upper right', fontsize=15)
    plt.show()
