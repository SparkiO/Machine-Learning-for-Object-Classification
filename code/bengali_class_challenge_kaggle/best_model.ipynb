# %% [markdown]
# ### Loading Files

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet

# %%
def change_size(df):
    preprocessed = {}
    for i in range(df.shape[0]):
        image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(64,64))
        image = image.reshape(-1)
        preprocessed[df.index[i]] = image
        
    preprocessed = pd.DataFrame(preprocessed).T
    return preprocessed

# %% [markdown]
# ### Model:

# %%
import tensorflow
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Activation, Conv2D, Flatten, Concatenate, GlobalAveragePooling2D, MaxPooling2D, AveragePooling2D, MaxPool2D, Dropout, BatchNormalization, Input, LeakyReLU
from tensorflow.keras import regularizers

inputs = Input(shape = (64, 64, 1))

VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(inputs)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(5, 5), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.3)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.3)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=512, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

#Classification Part
VGG_adjusted = Flatten()(VGG_adjusted)
VGG_adjusted = Dense(1024, activation = "relu")(VGG_adjusted)
VGG_adjusted = Dropout(0.30)(VGG_adjusted)
VGG_adjusted = Dense(512, activation = "relu")(VGG_adjusted)
VGG_adjusted = Dropout(0.30)(VGG_adjusted)

root = Dense(168, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='activation_1_root')(VGG_adjusted) 
vowel = Dense(11, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='activation_2_vowel')(VGG_adjusted) 
consonant = Dense(7, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='final_activation_consonant')(VGG_adjusted)

VGG_adjusted = Model(inputs=inputs, outputs=[root, vowel, consonant])

# %%
VGG_adjusted.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   102464      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 512)    1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 512)    2359808     batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 512)    6554112     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 2, 2, 512)    2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2, 2, 512)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1_root (Dense)       (None, 168)          86184       dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_2_vowel (Dense)      (None, 11)           5643        dropout_6[0][0]
# __________________________________________________________________________________________________
# final_activation_consonant (Den (None, 7)            3591        dropout_6[0][0]
# ==================================================================================================
# Total params: 17,846,906
# Trainable params: 17,838,842
# Non-trainable params: 8,064
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(VGG_adjusted)

# %%
from tensorflow.keras.optimizers import Adam

VGG_adjusted.compile(
        optimizer = Adam(lr= 1E-3, epsilon = 1e-8), 
        loss = "categorical_crossentropy", 
        metrics = ['accuracy']
        )

# %%
class DataGenerator(tensorflow.keras.preprocessing.image.ImageDataGenerator):
    
    def flow(self,x, y=None, batch_size=64, shuffle=True): 
        labels = None 
        keys = {} 
        ordered = []
        
        for key, value in y.items():
            labels = value if (labels is None) else (np.concatenate((labels, value), axis=1))
            keys[key] = value.shape[1] 
            ordered.append(key)

        for output_x, output_y in super().flow(x, labels, batch_size=64):
            label_dict = {}
            pos = 0
            
            for label in ordered:
                target_length = keys[label]
                label_dict[label] = output_y[:, pos: pos + target_length] 
                pos += target_length

            yield output_x, label_dict

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping 

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.1, mode="min", min_lr = 0.00001)
checkpoint = ModelCheckpoint('best_model_vgg_try.h5', monitor ='val_loss', save_best_only = True, save_weights_only=True)

callbacks = [reduce_learning_rate, checkpoint]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Training:

# %%
import gc
import tqdm
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv('../input/bengaliai-cv19/train.csv')

# %%
import cv2

# %%
histories = []
for i in range(4):
    print('Loading file:', i)
    df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df, on='image_id')

    grapheme = pd.get_dummies(df['grapheme_root']).values
    vowel = pd.get_dummies(df['vowel_diacritic']).values  
    consonant = pd.get_dummies(df['consonant_diacritic']).values

    df.drop(['image_id','grapheme_root','vowel_diacritic','consonant_diacritic','grapheme'], axis=1,inplace=True)
    df = change_size(df).astype('float32')

    df = df.values.reshape(-1, 64, 64, 1)
    df, test_x, train_graph_y, test_graph_y, train_vowel_y, test_vowel_y, train_cons_y, test_cons_y = train_test_split(df, grapheme,vowel,consonant, test_size=0.20)

    del grapheme
    del vowel
    del consonant
    gc.collect()

    gen = DataGenerator(rotation_range= 15, 
                        zoom_range = 0.10,
                        width_shift_range=0.10,
                        height_shift_range=0.10
                       )


    gen.fit(df)
    print('Training:')
    history = VGG_adjusted.fit_generator(gen.flow(df, {'activation_1_root': train_graph_y, 'activation_2_vowel': train_vowel_y, 'final_activation_consonant': train_cons_y}, batch_size= 64),
                                      epochs = 20,
                                      validation_data = (test_x, [test_graph_y, test_vowel_y, test_cons_y]),
                                      steps_per_epoch= df.shape[0] // 64,
                                      callbacks= callbacks,
                                      shuffle=True)
    histories.append(history)
    del history
    del df
    del test_vowel_y
    del train_cons_y
    del test_cons_y
    del gen
    del test_x
    del train_graph_y
    del test_graph_y
    del train_vowel_y
    gc.collect()
# Out:
# Loading file: 0
# Training:
# Train for 627 steps, validate on 10042 samples
# Epoch 1/20
# 627/627 [==============================] - 57s 91ms/step - loss: 7.9038 - activation_1_root_loss: 4.7043 - activation_2_vowel_loss: 1.4694 - final_activation_consonant_loss: 1.1616 - activation_1_root_accuracy: 0.0296 - activation_2_vowel_accuracy: 0.4799 - final_activation_consonant_accuracy: 0.6274 - val_loss: 7.3603 - val_activation_1_root_loss: 4.6700 - val_activation_2_vowel_loss: 1.4136 - val_final_activation_consonant_loss: 1.0843 - val_activation_1_root_accuracy: 0.0359 - val_activation_2_vowel_accuracy: 0.6160 - val_final_activation_consonant_accuracy: 0.6626
# Epoch 2/20
# 627/627 [==============================] - 49s 78ms/step - loss: 6.2883 - activation_1_root_loss: 4.4815 - activation_2_vowel_loss: 0.7689 - final_activation_consonant_loss: 0.8641 - activation_1_root_accuracy: 0.0343 - activation_2_vowel_accuracy: 0.7493 - final_activation_consonant_accuracy: 0.7080 - val_loss: 6.4599 - val_activation_1_root_loss: 4.4481 - val_activation_2_vowel_loss: 1.0588 - val_final_activation_consonant_loss: 0.7788 - val_activation_1_root_accuracy: 0.0439 - val_activation_2_vowel_accuracy: 0.6956 - val_final_activation_consonant_accuracy: 0.7513
# Epoch 3/20
# 627/627 [==============================] - 48s 77ms/step - loss: 5.6860 - activation_1_root_loss: 4.1874 - activation_2_vowel_loss: 0.6283 - final_activation_consonant_loss: 0.6901 - activation_1_root_accuracy: 0.0537 - activation_2_vowel_accuracy: 0.8017 - final_activation_consonant_accuracy: 0.7608 - val_loss: 5.3646 - val_activation_1_root_loss: 4.0442 - val_activation_2_vowel_loss: 0.5617 - val_final_activation_consonant_loss: 0.5694 - val_activation_1_root_accuracy: 0.0660 - val_activation_2_vowel_accuracy: 0.8272 - val_final_activation_consonant_accuracy: 0.8024
# Epoch 4/20
# 627/627 [==============================] - 47s 76ms/step - loss: 5.1197 - activation_1_root_loss: 3.8223 - activation_2_vowel_loss: 0.5408 - final_activation_consonant_loss: 0.5582 - activation_1_root_accuracy: 0.0786 - activation_2_vowel_accuracy: 0.8349 - final_activation_consonant_accuracy: 0.8088 - val_loss: 4.8296 - val_activation_1_root_loss: 3.6888 - val_activation_2_vowel_loss: 0.4176 - val_final_activation_consonant_loss: 0.5215 - val_activation_1_root_accuracy: 0.0976 - val_activation_2_vowel_accuracy: 0.8619 - val_final_activation_consonant_accuracy: 0.8192
# Epoch 5/20
# 627/627 [==============================] - 48s 77ms/step - loss: 4.7030 - activation_1_root_loss: 3.5263 - activation_2_vowel_loss: 0.4924 - final_activation_consonant_loss: 0.4796 - activation_1_root_accuracy: 0.1078 - activation_2_vowel_accuracy: 0.8494 - final_activation_consonant_accuracy: 0.8436 - val_loss: 4.1993 - val_activation_1_root_loss: 3.1806 - val_activation_2_vowel_loss: 0.4631 - val_final_activation_consonant_loss: 0.3468 - val_activation_1_root_accuracy: 0.1449 - val_activation_2_vowel_accuracy: 0.8640 - val_final_activation_consonant_accuracy: 0.8932
# Epoch 6/20
# 627/627 [==============================] - 48s 77ms/step - loss: 4.3239 - activation_1_root_loss: 3.2428 - activation_2_vowel_loss: 0.4594 - final_activation_consonant_loss: 0.4107 - activation_1_root_accuracy: 0.1427 - activation_2_vowel_accuracy: 0.8601 - final_activation_consonant_accuracy: 0.8704 - val_loss: 4.1971 - val_activation_1_root_loss: 3.0174 - val_activation_2_vowel_loss: 0.5105 - val_final_activation_consonant_loss: 0.4568 - val_activation_1_root_accuracy: 0.1752 - val_activation_2_vowel_accuracy: 0.8512 - val_final_activation_consonant_accuracy: 0.8433
# Epoch 7/20
# 627/627 [==============================] - 48s 77ms/step - loss: 4.0013 - activation_1_root_loss: 2.9905 - activation_2_vowel_loss: 0.4238 - final_activation_consonant_loss: 0.3732 - activation_1_root_accuracy: 0.1823 - activation_2_vowel_accuracy: 0.8720 - final_activation_consonant_accuracy: 0.8823 - val_loss: 3.4961 - val_activation_1_root_loss: 2.5868 - val_activation_2_vowel_loss: 0.3707 - val_final_activation_consonant_loss: 0.3224 - val_activation_1_root_accuracy: 0.2489 - val_activation_2_vowel_accuracy: 0.8953 - val_final_activation_consonant_accuracy: 0.9031
# Epoch 8/20
# 627/627 [==============================] - 47s 76ms/step - loss: 3.6851 - activation_1_root_loss: 2.7263 - activation_2_vowel_loss: 0.3921 - final_activation_consonant_loss: 0.3463 - activation_1_root_accuracy: 0.2306 - activation_2_vowel_accuracy: 0.8826 - final_activation_consonant_accuracy: 0.8936 - val_loss: 3.6056 - val_activation_1_root_loss: 2.7916 - val_activation_2_vowel_loss: 0.3348 - val_final_activation_consonant_loss: 0.2569 - val_activation_1_root_accuracy: 0.2349 - val_activation_2_vowel_accuracy: 0.8919 - val_final_activation_consonant_accuracy: 0.9263
# Epoch 9/20
# 627/627 [==============================] - 48s 76ms/step - loss: 3.4081 - activation_1_root_loss: 2.4844 - activation_2_vowel_loss: 0.3733 - final_activation_consonant_loss: 0.3266 - activation_1_root_accuracy: 0.2863 - activation_2_vowel_accuracy: 0.8892 - final_activation_consonant_accuracy: 0.9005 - val_loss: 2.6910 - val_activation_1_root_loss: 1.9822 - val_activation_2_vowel_loss: 0.2829 - val_final_activation_consonant_loss: 0.2012 - val_activation_1_root_accuracy: 0.3880 - val_activation_2_vowel_accuracy: 0.9136 - val_final_activation_consonant_accuracy: 0.9443
# Epoch 10/20
# 627/627 [==============================] - 48s 76ms/step - loss: 3.1799 - activation_1_root_loss: 2.2885 - activation_2_vowel_loss: 0.3544 - final_activation_consonant_loss: 0.3101 - activation_1_root_accuracy: 0.3348 - activation_2_vowel_accuracy: 0.8967 - final_activation_consonant_accuracy: 0.9066 - val_loss: 2.8924 - val_activation_1_root_loss: 2.0942 - val_activation_2_vowel_loss: 0.3036 - val_final_activation_consonant_loss: 0.2695 - val_activation_1_root_accuracy: 0.3818 - val_activation_2_vowel_accuracy: 0.9143 - val_final_activation_consonant_accuracy: 0.9212
# Epoch 11/20
# 627/627 [==============================] - 48s 77ms/step - loss: 1.6401 - activation_1_root_loss: 1.0224 - activation_2_vowel_loss: 0.2171 - final_activation_consonant_loss: 0.1868 - activation_1_root_accuracy: 0.7187 - activation_2_vowel_accuracy: 0.9427 - final_activation_consonant_accuracy: 0.9483 - val_loss: 1.2432 - val_activation_1_root_loss: 0.7241 - val_activation_2_vowel_loss: 0.1676 - val_final_activation_consonant_loss: 0.1382 - val_activation_1_root_accuracy: 0.7989 - val_activation_2_vowel_accuracy: 0.9590 - val_final_activation_consonant_accuracy: 0.9626
# Loading file: 1
# Training:
# Train for 627 steps, validate on 10042 samples
# Epoch 1/20
# 627/627 [==============================] - 48s 76ms/step - loss: 1.2723 - activation_1_root_loss: 0.7361 - activation_2_vowel_loss: 0.1790 - final_activation_consonant_loss: 0.1612 - activation_1_root_accuracy: 0.8069 - activation_2_vowel_accuracy: 0.9551 - final_activation_consonant_accuracy: 0.9551 - val_loss: 0.9990 - val_activation_1_root_loss: 0.5641 - val_activation_2_vowel_loss: 0.1156 - val_final_activation_consonant_loss: 0.1250 - val_activation_1_root_accuracy: 0.8607 - val_activation_2_vowel_accuracy: 0.9717 - val_final_activation_consonant_accuracy: 0.9673
# Epoch 9/20
# 626/627 [============================>.] - ETA: 0s - loss: 1.2248 - activation_1_root_loss: 0.6983 - activation_2_vowel_loss: 0.1758 - final_activation_consonant_loss: 0.1574 - activation_1_root_accuracy: 0.8178 - activation_2_vowel_accuracy: 0.9571 - final_activation_consonant_accuracy: 0.9573
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 627/627 [==============================] - 48s 76ms/step - loss: 1.2246 - activation_1_root_loss: 0.6980 - activation_2_vowel_loss: 0.1761 - final_activation_consonant_loss: 0.1572 - activation_1_root_accuracy: 0.8179 - activation_2_vowel_accuracy: 0.9571 - final_activation_consonant_accuracy: 0.9574 - val_loss: 0.9673 - val_activation_1_root_loss: 0.5416 - val_activation_2_vowel_loss: 0.1291 - val_final_activation_consonant_loss: 0.1043 - val_activation_1_root_accuracy: 0.8668 - val_activation_2_vowel_accuracy: 0.9689 - val_final_activation_consonant_accuracy: 0.9730
# Epoch 10/20
# 627/627 [==============================] - 48s 77ms/step - loss: 0.5997 - activation_1_root_loss: 0.3351 - activation_2_vowel_loss: 0.0795 - final_activation_consonant_loss: 0.0807 - activation_1_root_accuracy: 0.9093 - activation_2_vowel_accuracy: 0.9800 - final_activation_consonant_accuracy: 0.9784 - val_loss: 0.5871 - val_activation_1_root_loss: 0.3343 - val_activation_2_vowel_loss: 0.0751 - val_final_activation_consonant_loss: 0.0757 - val_activation_1_root_accuracy: 0.9177 - val_activation_2_vowel_accuracy: 0.9830 - val_final_activation_consonant_accuracy: 0.9796
# Epoch 19/20
# 627/627 [==============================] - 48s 77ms/step - loss: 0.7112 - activation_1_root_loss: 0.4257 - activation_2_vowel_loss: 0.1021 - final_activation_consonant_loss: 0.0995 - activation_1_root_accuracy: 0.8893 - activation_2_vowel_accuracy: 0.9749 - final_activation_consonant_accuracy: 0.9727 - val_loss: 0.5153 - val_activation_1_root_loss: 0.2909 - val_activation_2_vowel_loss: 0.0688 - val_final_activation_consonant_loss: 0.0728 - val_activation_1_root_accuracy: 0.9233 - val_activation_2_vowel_accuracy: 0.9851 - val_final_activation_consonant_accuracy: 0.9791
# Epoch 6/20
# 627/627 [==============================] - 48s 76ms/step - loss: 0.5695 - activation_1_root_loss: 0.3361 - activation_2_vowel_loss: 0.0810 - final_activation_consonant_loss: 0.0798 - activation_1_root_accuracy: 0.9098 - activation_2_vowel_accuracy: 0.9792 - final_activation_consonant_accuracy: 0.9788 - val_loss: 0.4955 - val_activation_1_root_loss: 0.2834 - val_activation_2_vowel_loss: 0.0678 - val_final_activation_consonant_loss: 0.0719 - val_activation_1_root_accuracy: 0.9283 - val_activation_2_vowel_accuracy: 0.9860 - val_final_activation_consonant_accuracy: 0.9803
# Epoch 17/20
# 627/627 [==============================] - 48s 77ms/step - loss: 0.7110 - activation_1_root_loss: 0.4319 - activation_2_vowel_loss: 0.1083 - final_activation_consonant_loss: 0.1011 - activation_1_root_accuracy: 0.8916 - activation_2_vowel_accuracy: 0.9746 - final_activation_consonant_accuracy: 0.9722 - val_loss: 0.4530 - val_activation_1_root_loss: 0.2651 - val_activation_2_vowel_loss: 0.0587 - val_final_activation_consonant_loss: 0.0598 - val_activation_1_root_accuracy: 0.9308 - val_activation_2_vowel_accuracy: 0.9864 - val_final_activation_consonant_accuracy: 0.9834
# Epoch 4/20
# 627/627 [==============================] - 48s 77ms/step - loss: 0.6492 - activation_1_root_loss: 0.3894 - activation_2_vowel_loss: 0.0987 - final_activation_consonant_loss: 0.0942 - activation_1_root_accuracy: 0.9004 - activation_2_vowel_accuracy: 0.9751 - final_activation_consonant_accuracy: 0.9738 - val_loss: 0.4424 - val_activation_1_root_loss: 0.2596 - val_activation_2_vowel_loss: 0.0577 - val_final_activation_consonant_loss: 0.0586 - val_activation_1_root_accuracy: 0.9326 - val_activation_2_vowel_accuracy: 0.9867 - val_final_activation_consonant_accuracy: 0.9841
# Epoch 15/20
# 627/627 [==============================] - 47s 76ms/step - loss: 0.6414 - activation_1_root_loss: 0.3871 - activation_2_vowel_loss: 0.0954 - final_activation_consonant_loss: 0.0923 - activation_1_root_accuracy: 0.9010 - activation_2_vowel_accuracy: 0.9770 - final_activation_consonant_accuracy: 0.9737 - val_loss: 0.4432 - val_activation_1_root_loss: 0.2604 - val_activation_2_vowel_loss: 0.0581 - val_final_activation_consonant_loss: 0.0585 - val_activation_1_root_accuracy: 0.9319 - val_activation_2_vowel_accuracy: 0.9861 - val_final_activation_consonant_accuracy: 0.9842
# Epoch 16/20
# 627/627 [==============================] - 47s 76ms/step - loss: 0.6444 - activation_1_root_loss: 0.3919 - activation_2_vowel_loss: 0.0927 - final_activation_consonant_loss: 0.0934 - activation_1_root_accuracy: 0.8979 - activation_2_vowel_accuracy: 0.9765 - final_activation_consonant_accuracy: 0.9749 - val_loss: 0.4426 - val_activation_1_root_loss: 0.2598 - val_activation_2_vowel_loss: 0.0583 - val_final_activation_consonant_loss: 0.0585 - val_activation_1_root_accuracy: 0.9327 - val_activation_2_vowel_accuracy: 0.9863 - val_final_activation_consonant_accuracy: 0.9839
# Epoch 17/20
# 160/627 [======>.......................] - ETA: 32s - loss: 0.6298 - activation_1_root_loss: 0.3743 - activation_2_vowel_loss: 0.0950 - final_activation_consonant_loss: 0.0943 - activation_1_root_accuracy: 0.9046 - activation_2_vowel_accuracy: 0.9759 - final_activation_consonant_accuracy: 0.9740

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
for history in histories:
    plt.figure(figsize=(25, 10), dpi=100)

    plt.title('Training Loss Graph', fontsize=25)
    plt.xlabel('Epoch', fontsize=20)
    plt.ylabel('Loss', fontsize=20)
    plt.ylim(0, 8)
    
    plt.plot(np.arange(0.0, 20), history.history['activation_1_root_loss'], label='train_root')
    plt.plot(np.arange(0.0, 20), history.history['activation_2_vowel_loss'], label='train_vowel')
    plt.plot(np.arange(0.0, 20), history.history['final_activation_consonant_loss'], label='train_consonant')

    plt.plot(np.arange(0.0, 20), history.history['val_activation_1_root_loss'], label='val_root')
    plt.plot(np.arange(0.0, 20), history.history['val_activation_2_vowel_loss'], label='val_vowel')
    plt.plot(np.arange(0.0, 20), history.history['val_final_activation_consonant_loss'], label='val_consonant')

    plt.legend(loc='upper right', fontsize=15)
    plt.show()

# %%
for history in histories:
    plt.figure(figsize=(25, 10), dpi=100)

    plt.title('Training Accuracy Graph', fontsize=25)
    plt.xlabel('Epoch', fontsize=20)
    plt.ylabel('Accuracy', fontsize=20)
    plt.ylim(0, 1)

    plt.plot(np.arange(0.0, 20), history.history['activation_1_root_accuracy'], label='train_root')
    plt.plot(np.arange(0.0, 20), history.history['activation_2_vowel_accuracy'], label='train_vowel')
    plt.plot(np.arange(0.0, 20), history.history['final_activation_consonant_accuracy'], label='train_consonant')

    plt.plot(np.arange(0.0, 20), history.history['val_activation_1_root_accuracy'], label='val_root')
    plt.plot(np.arange(0.0, 20), history.history['val_activation_2_vowel_accuracy'], label='val_vowel')
    plt.plot(np.arange(0.0, 20), history.history['val_final_activation_consonant_accuracy'], label='val_consonant')

    plt.legend(loc='upper right', fontsize=15)
    plt.show()
