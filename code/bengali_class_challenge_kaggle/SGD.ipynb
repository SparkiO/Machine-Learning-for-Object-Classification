# %% [markdown]
# ### Loading Files

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train.csv

# %%
def change_size(df):
    preprocessed = {}
    for i in range(df.shape[0]):
        image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(64,64))
        image = image.reshape(-1)
        preprocessed[df.index[i]] = image
        
    preprocessed = pd.DataFrame(preprocessed).T
    return preprocessed

# %% [markdown]
# ### Model:

# %%
import tensorflow
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Activation, Conv2D, Flatten, Concatenate, GlobalAveragePooling2D, MaxPooling2D, AveragePooling2D, MaxPool2D, Dropout, BatchNormalization, Input, LeakyReLU
from tensorflow.keras import regularizers

inputs = Input(shape = (64, 64, 1))

VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(inputs)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=32, kernel_size=(5, 5), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.3)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(VGG_adjusted)
VGG_adjusted = LeakyReLU()(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.3)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=128, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=256, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

VGG_adjusted = Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(VGG_adjusted)

VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = MaxPool2D((2, 2))(VGG_adjusted)
VGG_adjusted = Conv2D(filters=512, kernel_size=(5, 5), padding='same', activation='relu')(VGG_adjusted)
VGG_adjusted = BatchNormalization()(VGG_adjusted)
VGG_adjusted = Dropout(0.2)(VGG_adjusted)

#Classification Part
VGG_adjusted = Flatten()(VGG_adjusted)
VGG_adjusted = Dense(1024, activation = "relu")(VGG_adjusted)
VGG_adjusted = Dropout(0.30)(VGG_adjusted)
VGG_adjusted = Dense(512, activation = "relu")(VGG_adjusted)
VGG_adjusted = Dropout(0.30)(VGG_adjusted)

root = Dense(168, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='activation_1_root')(VGG_adjusted) 
vowel = Dense(11, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='activation_2_vowel')(VGG_adjusted) 
consonant = Dense(7, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='final_activation_consonant')(VGG_adjusted)

VGG_adjusted = Model(inputs=inputs, outputs=[root, vowel, consonant])

# %%
VGG_adjusted.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   102464      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 512)    1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 512)    2359808     batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 512)    6554112     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 2, 2, 512)    2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2, 2, 512)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1_root (Dense)       (None, 168)          86184       dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_2_vowel (Dense)      (None, 11)           5643        dropout_6[0][0]
# __________________________________________________________________________________________________
# final_activation_consonant (Den (None, 7)            3591        dropout_6[0][0]
# ==================================================================================================
# Total params: 17,846,906
# Trainable params: 17,838,842
# Non-trainable params: 8,064
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(VGG_adjusted)

# %%
from tensorflow.keras.optimizers import SGD

VGG_adjusted.compile(
        optimizer = SGD(lr= 1E-3), 
        loss = "categorical_crossentropy", 
        metrics = ['accuracy']
        )

# %%
class DataGenerator(tensorflow.keras.preprocessing.image.ImageDataGenerator):
    
    def flow(self,x, y=None, batch_size=64, shuffle=True): 
        labels = None 
        keys = {} 
        ordered = []
        
        for key, value in y.items():
            labels = value if (labels is None) else (np.concatenate((labels, value), axis=1))
            keys[key] = value.shape[1] 
            ordered.append(key)

        for output_x, output_y in super().flow(x, labels, batch_size=64):
            label_dict = {}
            pos = 0
            
            for label in ordered:
                target_length = keys[label]
                label_dict[label] = output_y[:, pos: pos + target_length] 
                pos += target_length

            yield output_x, label_dict

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping 

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.1, mode="min", min_lr = 0.00001)
checkpoint = ModelCheckpoint('best_model_vgg_try.h5', monitor ='val_loss', save_best_only = True, save_weights_only=True)

callbacks = [reduce_learning_rate, checkpoint]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Training:

# %%
import gc
import tqdm
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv('../input/bengaliai-cv19/train.csv')

# %%
import cv2

# %%
histories = []
for i in range(4):
    print('Loading file:', i)
    df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df, on='image_id')

    grapheme = pd.get_dummies(df['grapheme_root']).values
    vowel = pd.get_dummies(df['vowel_diacritic']).values  
    consonant = pd.get_dummies(df['consonant_diacritic']).values

    df.drop(['image_id','grapheme_root','vowel_diacritic','consonant_diacritic','grapheme'], axis=1,inplace=True)
    df = change_size(df).astype('float32')

    df = df.values.reshape(-1, 64, 64, 1)
    df, test_x, train_graph_y, test_graph_y, train_vowel_y, test_vowel_y, train_cons_y, test_cons_y = train_test_split(df, grapheme,vowel,consonant, test_size=0.20)

    del grapheme
    del vowel
    del consonant
    gc.collect()

    gen = DataGenerator(rotation_range= 15, 
                        zoom_range = 0.10,
                        width_shift_range=0.10,
                        height_shift_range=0.10
                       )


    gen.fit(df)
    print('Training:')
    history = VGG_adjusted.fit_generator(gen.flow(df, {'activation_1_root': train_graph_y, 'activation_2_vowel': train_vowel_y, 'final_activation_consonant': train_cons_y}, batch_size= 64),
                                      epochs = 20,
                                      validation_data = (test_x, [test_graph_y, test_vowel_y, test_cons_y]),
                                      steps_per_epoch= df.shape[0] // 64,
                                      callbacks= callbacks,
                                      shuffle=True)
    histories.append(history)
    del history
    del df
    del test_vowel_y
    del train_cons_y
    del test_cons_y
    del gen
    del test_x
    del train_graph_y
    del test_graph_y
    del train_vowel_y
    gc.collect()
# Out:
# Loading file: 0
# Training:
# Train for 627 steps, validate on 10042 samples
# Epoch 1/20
# 627/627 [==============================] - 56s 90ms/step - loss: 11.3890 - activation_1_root_loss: 5.1077 - activation_2_vowel_loss: 2.1326 - final_activation_consonant_loss: 1.3006 - activation_1_root_accuracy: 0.0188 - activation_2_vowel_accuracy: 0.2471 - final_activation_consonant_accuracy: 0.6021 - val_loss: 10.5353 - val_activation_1_root_loss: 4.8688 - val_activation_2_vowel_loss: 1.6838 - val_final_activation_consonant_loss: 1.1723 - val_activation_1_root_accuracy: 0.0283 - val_activation_2_vowel_accuracy: 0.4237 - val_final_activation_consonant_accuracy: 0.6178
# Epoch 2/20
# 627/627 [==============================] - 49s 78ms/step - loss: 10.4669 - activation_1_root_loss: 4.9167 - activation_2_vowel_loss: 1.5993 - final_activation_consonant_loss: 1.1766 - activation_1_root_accuracy: 0.0270 - activation_2_vowel_accuracy: 0.4447 - final_activation_consonant_accuracy: 0.6137 - val_loss: 9.9092 - val_activation_1_root_loss: 4.7689 - val_activation_2_vowel_loss: 1.3248 - val_final_activation_consonant_loss: 1.0766 - val_activation_1_root_accuracy: 0.0335 - val_activation_2_vowel_accuracy: 0.5341 - val_final_activation_consonant_accuracy: 0.6274
# Epoch 3/20
# 627/627 [==============================] - 48s 77ms/step - loss: 9.8757 - activation_1_root_loss: 4.8597 - activation_2_vowel_loss: 1.2070 - final_activation_consonant_loss: 1.1051 - activation_1_root_accuracy: 0.0285 - activation_2_vowel_accuracy: 0.5929 - final_activation_consonant_accuracy: 0.6182 - val_loss: 9.1639 - val_activation_1_root_loss: 4.6840 - val_activation_2_vowel_loss: 0.8526 - val_final_activation_consonant_loss: 0.9582 - val_activation_1_root_accuracy: 0.0389 - val_activation_2_vowel_accuracy: 0.7024 - val_final_activation_consonant_accuracy: 0.6423
# Epoch 4/20
# 627/627 [==============================] - 48s 77ms/step - loss: 9.5170 - activation_1_root_loss: 4.7984 - activation_2_vowel_loss: 1.0383 - final_activation_consonant_loss: 1.0450 - activation_1_root_accuracy: 0.0322 - activation_2_vowel_accuracy: 0.6504 - final_activation_consonant_accuracy: 0.6287 - val_loss: 9.6903 - val_activation_1_root_loss: 4.6663 - val_activation_2_vowel_loss: 1.3922 - val_final_activation_consonant_loss: 1.0301 - val_activation_1_root_accuracy: 0.0375 - val_activation_2_vowel_accuracy: 0.5238 - val_final_activation_consonant_accuracy: 0.6356
# Epoch 5/20
# 627/627 [==============================] - 48s 77ms/step - loss: 9.2754 - activation_1_root_loss: 4.7508 - activation_2_vowel_loss: 0.9512 - final_activation_consonant_loss: 1.0046 - activation_1_root_accuracy: 0.0319 - activation_2_vowel_accuracy: 0.6768 - final_activation_consonant_accuracy: 0.6428 - val_loss: 8.8016 - val_activation_1_root_loss: 4.5977 - val_activation_2_vowel_loss: 0.7453 - val_final_activation_consonant_loss: 0.9226 - val_activation_1_root_accuracy: 0.0454 - val_activation_2_vowel_accuracy: 0.7357 - val_final_activation_consonant_accuracy: 0.6359
# Epoch 6/20
# 627/627 [==============================] - 48s 77ms/step - loss: 9.0711 - activation_1_root_loss: 4.7182 - activation_2_vowel_loss: 0.8865 - final_activation_consonant_loss: 0.9624 - activation_1_root_accuracy: 0.0350 - activation_2_vowel_accuracy: 0.6994 - final_activation_consonant_accuracy: 0.6522 - val_loss: 8.6925 - val_activation_1_root_loss: 4.5595 - val_activation_2_vowel_loss: 0.7541 - val_final_activation_consonant_loss: 0.9067 - val_activation_1_root_accuracy: 0.0482 - val_activation_2_vowel_accuracy: 0.7257 - val_final_activation_consonant_accuracy: 0.6499
# Epoch 7/20
# 627/627 [==============================] - 49s 78ms/step - loss: 8.8672 - activation_1_root_loss: 4.6786 - activation_2_vowel_loss: 0.8249 - final_activation_consonant_loss: 0.9227 - activation_1_root_accuracy: 0.0372 - activation_2_vowel_accuracy: 0.7164 - final_activation_consonant_accuracy: 0.6661 - val_loss: 8.3369 - val_activation_1_root_loss: 4.5044 - val_activation_2_vowel_loss: 0.6415 - val_final_activation_consonant_loss: 0.7811 - val_activation_1_root_accuracy: 0.0517 - val_activation_2_vowel_accuracy: 0.7735 - val_final_activation_consonant_accuracy: 0.7163
# Epoch 8/20
# 627/627 [==============================] - 49s 78ms/step - loss: 8.6851 - activation_1_root_loss: 4.6468 - activation_2_vowel_loss: 0.7877 - final_activation_consonant_loss: 0.8709 - activation_1_root_accuracy: 0.0376 - activation_2_vowel_accuracy: 0.7310 - final_activation_consonant_accuracy: 0.6834 - val_loss: 9.3517 - val_activation_1_root_loss: 4.5578 - val_activation_2_vowel_loss: 1.5676 - val_final_activation_consonant_loss: 0.8767 - val_activation_1_root_accuracy: 0.0405 - val_activation_2_vowel_accuracy: 0.4931 - val_final_activation_consonant_accuracy: 0.6936
# Epoch 9/20
# 627/627 [==============================] - 49s 78ms/step - loss: 8.4971 - activation_1_root_loss: 4.6082 - activation_2_vowel_loss: 0.7506 - final_activation_consonant_loss: 0.8184 - activation_1_root_accuracy: 0.0413 - activation_2_vowel_accuracy: 0.7431 - final_activation_consonant_accuracy: 0.7039 - val_loss: 7.9502 - val_activation_1_root_loss: 4.4050 - val_activation_2_vowel_loss: 0.5776 - val_final_activation_consonant_loss: 0.6770 - val_activation_1_root_accuracy: 0.0583 - val_activation_2_vowel_accuracy: 0.7972 - val_final_activation_consonant_accuracy: 0.7551
# Epoch 10/20
# 627/627 [==============================] - 49s 78ms/step - loss: 8.3131 - activation_1_root_loss: 4.5642 - activation_2_vowel_loss: 0.7153 - final_activation_consonant_loss: 0.7715 - activation_1_root_accuracy: 0.0448 - activation_2_vowel_accuracy: 0.7560 - final_activation_consonant_accuracy: 0.7200 - val_loss: 8.2520 - val_activation_1_root_loss: 4.4762 - val_activation_2_vowel_loss: 0.7425 - val_final_activation_consonant_loss: 0.8000 - val_activation_1_root_accuracy: 0.0520 - val_activation_2_vowel_accuracy: 0.7285 - val_final_activation_consonant_accuracy: 0.7115
# Epoch 11/20
# 627/627 [==============================] - 48s 77ms/step - loss: 7.2781 - activation_1_root_loss: 4.2033 - activation_2_vowel_loss: 0.5499 - final_activation_consonant_loss: 0.5777 - activation_1_root_accuracy: 0.0700 - activation_2_vowel_accuracy: 0.8144 - final_activation_consonant_accuracy: 0.7931 - val_loss: 7.0155 - val_activation_1_root_loss: 4.0382 - val_activation_2_vowel_loss: 0.5045 - val_final_activation_consonant_loss: 0.5281 - val_activation_1_root_accuracy: 0.0903 - val_activation_2_vowel_accuracy: 0.8302 - val_final_activation_consonant_accuracy: 0.8115
# Loading file: 1
# Training:
# Train for 627 steps, validate on 10042 samples
# Epoch 1/20
# 627/627 [==============================] - 48s 76ms/step - loss: 7.2592 - activation_1_root_loss: 4.2050 - activation_2_vowel_loss: 0.5471 - final_activation_consonant_loss: 0.5787 - activation_1_root_accuracy: 0.0688 - activation_2_vowel_accuracy: 0.8186 - final_activation_consonant_accuracy: 0.7937 - val_loss: 6.8698 - val_activation_1_root_loss: 3.9843 - val_activation_2_vowel_loss: 0.4611 - val_final_activation_consonant_loss: 0.4962 - val_activation_1_root_accuracy: 0.0963 - val_activation_2_vowel_accuracy: 0.8472 - val_final_activation_consonant_accuracy: 0.8208
# Epoch 8/20
# 627/627 [==============================] - 48s 77ms/step - loss: 7.2611 - activation_1_root_loss: 4.2043 - activation_2_vowel_loss: 0.5507 - final_activation_consonant_loss: 0.5781 - activation_1_root_accuracy: 0.0692 - activation_2_vowel_accuracy: 0.8185 - final_activation_consonant_accuracy: 0.7935 - val_loss: 6.8596 - val_activation_1_root_loss: 3.9809 - val_activation_2_vowel_loss: 0.4575 - val_final_activation_consonant_loss: 0.4935 - val_activation_1_root_accuracy: 0.0977 - val_activation_2_vowel_accuracy: 0.8502 - val_final_activation_consonant_accuracy: 0.8228
# Epoch 9/20
# 627/627 [==============================] - 48s 77ms/step - loss: 7.2506 - activation_1_root_loss: 4.1953 - activation_2_vowel_loss: 0.5501 - final_activation_consonant_loss: 0.5778 - activation_1_root_accuracy: 0.0686 - activation_2_vowel_accuracy: 0.8174 - final_activation_consonant_accuracy: 0.7932 - val_loss: 6.8467 - val_activation_1_root_loss: 3.9729 - val_activation_2_vowel_loss: 0.4572 - val_final_activation_consonant_loss: 0.4895 - val_activation_1_root_accuracy: 0.0974 - val_activation_2_vowel_accuracy: 0.8504 - val_final_activation_consonant_accuracy: 0.8241
# Epoch 10/20
# 627/627 [==============================] - 48s 77ms/step - loss: 7.2389 - activation_1_root_loss: 4.1925 - activation_2_vowel_loss: 0.5442 - final_activation_consonant_loss: 0.5824 - activation_1_root_accuracy: 0.0708 - activation_2_vowel_accuracy: 0.8215 - final_activation_consonant_accuracy: 0.7932 - val_loss: 6.7880 - val_activation_1_root_loss: 3.9315 - val_activation_2_vowel_loss: 0.4585 - val_final_activation_consonant_loss: 0.4784 - val_activation_1_root_accuracy: 0.1047 - val_activation_2_vowel_accuracy: 0.8421 - val_final_activation_consonant_accuracy: 0.8267
# Epoch 6/20
# 627/627 [==============================] - 48s 76ms/step - loss: 7.2210 - activation_1_root_loss: 4.1855 - activation_2_vowel_loss: 0.5448 - final_activation_consonant_loss: 0.5758 - activation_1_root_accuracy: 0.0709 - activation_2_vowel_accuracy: 0.8194 - final_activation_consonant_accuracy: 0.7946 - val_loss: 6.7591 - val_activation_1_root_loss: 3.9171 - val_activation_2_vowel_loss: 0.4539 - val_final_activation_consonant_loss: 0.4732 - val_activation_1_root_accuracy: 0.1072 - val_activation_2_vowel_accuracy: 0.8437 - val_final_activation_consonant_accuracy: 0.8278
# Epoch 16/20
# 627/627 [==============================] - 47s 76ms/step - loss: 7.2051 - activation_1_root_loss: 4.1767 - activation_2_vowel_loss: 0.5461 - final_activation_consonant_loss: 0.5707 - activation_1_root_accuracy: 0.0717 - activation_2_vowel_accuracy: 0.8190 - final_activation_consonant_accuracy: 0.7946 - val_loss: 6.7775 - val_activation_1_root_loss: 3.9205 - val_activation_2_vowel_loss: 0.4656 - val_final_activation_consonant_loss: 0.4800 - val_activation_1_root_accuracy: 0.1044 - val_activation_2_vowel_accuracy: 0.8437 - val_final_activation_consonant_accuracy: 0.8248
# Epoch 3/20
# 627/627 [==============================] - 49s 78ms/step - loss: 7.1753 - activation_1_root_loss: 4.1643 - activation_2_vowel_loss: 0.5399 - final_activation_consonant_loss: 0.5648 - activation_1_root_accuracy: 0.0748 - activation_2_vowel_accuracy: 0.8203 - final_activation_consonant_accuracy: 0.7994 - val_loss: 6.7363 - val_activation_1_root_loss: 3.9064 - val_activation_2_vowel_loss: 0.4540 - val_final_activation_consonant_loss: 0.4698 - val_activation_1_root_accuracy: 0.1071 - val_activation_2_vowel_accuracy: 0.8497 - val_final_activation_consonant_accuracy: 0.8297
# Epoch 14/20
# 627/627 [==============================] - 49s 77ms/step - loss: 7.1780 - activation_1_root_loss: 4.1611 - activation_2_vowel_loss: 0.5424 - final_activation_consonant_loss: 0.5687 - activation_1_root_accuracy: 0.0745 - activation_2_vowel_accuracy: 0.8185 - final_activation_consonant_accuracy: 0.7973 - val_loss: 6.7555 - val_activation_1_root_loss: 3.9063 - val_activation_2_vowel_loss: 0.4694 - val_final_activation_consonant_loss: 0.4743 - val_activation_1_root_accuracy: 0.1062 - val_activation_2_vowel_accuracy: 0.8417 - val_final_activation_consonant_accuracy: 0.8278
# Epoch 15/20
# 627/627 [==============================] - 49s 77ms/step - loss: 7.1769 - activation_1_root_loss: 4.1621 - activation_2_vowel_loss: 0.5393 - final_activation_consonant_loss: 0.5701 - activation_1_root_accuracy: 0.0746 - activation_2_vowel_accuracy: 0.8198 - final_activation_consonant_accuracy: 0.7975 - val_loss: 6.7292 - val_activation_1_root_loss: 3.8969 - val_activation_2_vowel_loss: 0.4584 - val_final_activation_consonant_loss: 0.4689 - val_activation_1_root_accuracy: 0.1066 - val_activation_2_vowel_accuracy: 0.8468 - val_final_activation_consonant_accuracy: 0.8299
# Epoch 16/20
# 295/627 [=============>................] - ETA: 23s - loss: 7.2064 - activation_1_root_loss: 4.1869 - activation_2_vowel_loss: 0.5492 - final_activation_consonant_loss: 0.5652 - activation_1_root_accuracy: 0.0738 - activation_2_vowel_accuracy: 0.8143 - final_activation_consonant_accuracy: 0.7989

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
for history in histories:
    plt.figure(figsize=(25, 10), dpi=100)

    plt.title('Training Loss Graph', fontsize=25)
    plt.xlabel('Epoch', fontsize=20)
    plt.ylabel('Loss', fontsize=20)
    plt.ylim(0, 8)
    
    plt.plot(np.arange(0.0, 20), history.history['activation_1_root_loss'], label='train_root')
    plt.plot(np.arange(0.0, 20), history.history['activation_2_vowel_loss'], label='train_vowel')
    plt.plot(np.arange(0.0, 20), history.history['final_activation_consonant_loss'], label='train_consonant')

    plt.plot(np.arange(0.0, 20), history.history['val_activation_1_root_loss'], label='val_root')
    plt.plot(np.arange(0.0, 20), history.history['val_activation_2_vowel_loss'], label='val_vowel')
    plt.plot(np.arange(0.0, 20), history.history['val_final_activation_consonant_loss'], label='val_consonant')

    plt.legend(loc='upper right', fontsize=15)
    plt.show()

# %%
for history in histories:
    plt.figure(figsize=(25, 10), dpi=100)

    plt.title('Training Accuracy Graph', fontsize=25)
    plt.xlabel('Epoch', fontsize=20)
    plt.ylabel('Accuracy', fontsize=20)
    plt.ylim(0, 1)

    plt.plot(np.arange(0.0, 20), history.history['activation_1_root_accuracy'], label='train_root')
    plt.plot(np.arange(0.0, 20), history.history['activation_2_vowel_accuracy'], label='train_vowel')
    plt.plot(np.arange(0.0, 20), history.history['final_activation_consonant_accuracy'], label='train_consonant')

    plt.plot(np.arange(0.0, 20), history.history['val_activation_1_root_accuracy'], label='val_root')
    plt.plot(np.arange(0.0, 20), history.history['val_activation_2_vowel_accuracy'], label='val_vowel')
    plt.plot(np.arange(0.0, 20), history.history['val_final_activation_consonant_accuracy'], label='val_consonant')

    plt.legend(loc='upper right', fontsize=15)
    plt.show()
